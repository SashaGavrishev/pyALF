# %% [markdown]
# # Presentation of new pyALF features

# %% [markdown]
# **1.** Import `Simulation` class from the `py_alf` python module, which provides the interface with ALF:

# %%
# Activate matplotlib Jupyter widgets
# %matplotlib widget

# %%
import numpy as np

from py_alf import ALF_source, Simulation  # Interface with ALF

# %%
alf_src = ALF_source()

# %% [markdown]
# **2.** Create an instance of `Simulation`, setting parameters as desired:

# %% [markdown]
# **New:** Proper support for Parallel Tempering

# %%
sim = Simulation(
    alf_src,
    "Hubbard",
    [{
        'L1': 4,
        'L2': 4,
        "Nsweep": 1,
        "Nbin": 1000,
        "Lattice_type": "Square",
        "Ham_U": U,
        "mpi_per_parameter_set": 1
    } for U in [1, 2, 3, 4]
    ],
    n_mpi=4,
    machine='gnu',
    # parallel_params=True  # This option enables independent simulations in parallel.
)

# %% [markdown]
# **3.** Compile ALF, downloading it first from the [ALF repository](https://github.com/ALF-QMC/ALF/-/tree/master/) if not found locally. This may take a few minutes:

# %%
sim.compile()
# Out:
# Compiling ALF...
# Cleaning up Prog/
# Cleaning up Libraries/
# Cleaning up Analysis/
# Compiling Libraries
# ar: creating modules_90.a
# ar: creating libqrref.a
# Compiling Analysis
# Compiling Program
# Parsing Hamiltonian parameters
# filenames: Hamiltonians/Hamiltonian_Kondo_smod.F90 Hamiltonians/Hamiltonian_Kondo_read_write_parameters.F90
# filenames: Hamiltonians/Hamiltonian_Hubbard_smod.F90 Hamiltonians/Hamiltonian_Hubbard_read_write_parameters.F90
# filenames: Hamiltonians/Hamiltonian_Hubbard_Plain_Vanilla_smod.F90 Hamiltonians/Hamiltonian_Hubbard_Plain_Vanilla_read_write_parameters.F90
# filenames: Hamiltonians/Hamiltonian_tV_smod.F90 Hamiltonians/Hamiltonian_tV_read_write_parameters.F90
# filenames: Hamiltonians/Hamiltonian_LRC_smod.F90 Hamiltonians/Hamiltonian_LRC_read_write_parameters.F90
# filenames: Hamiltonians/Hamiltonian_Z2_Matter_smod.F90 Hamiltonians/Hamiltonian_Z2_Matter_read_write_parameters.F90
# filenames: Hamiltonians/Hamiltonian_Spin_Peierls_smod.F90 Hamiltonians/Hamiltonian_Spin_Peierls_read_write_parameters.F90
# Compiling program modules
# Link program
# Done.

# %% [markdown]
# **4.** Perform the simulation as specified in `sim`:

# %%
sim.run()
# Out:
# Prepare directory "/home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1" for Monte Carlo run.
# Create new directory.
# Prepare directory "/home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1/Temp_0" for Monte Carlo run.
# Create new directory.
# Prepare directory "/home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1/Temp_1" for Monte Carlo run.
# Create new directory.
# Prepare directory "/home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1/Temp_2" for Monte Carlo run.
# Create new directory.
# Prepare directory "/home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1/Temp_3" for Monte Carlo run.
# Create new directory.
# Run /home/jonas/Programs/ALF/Prog/ALF.out
#  ALF Copyright (C) 2016 - 2022 The ALF project contributors
#  This Program comes with ABSOLUTELY NO WARRANTY; for details see license.GPL
#  This is free software, and you are welcome to redistribute it under certain conditions.
#  No initial configuration

# %% [markdown]
# **New:** Derived observables

# %%
custom_obs = {}

# %%
def obs_squared(obs, sign, N_obs):
    return obs[0]**2 / sign

# Energy squared
custom_obs['E_squared']= {
    'needs': ['Ener_scal'],
    'function': obs_squared,
    'kwargs': {}
}

# %%
def E_pot_kin(E_pot_obs, E_pot_sign, E_pot_N_obs, E_kin_obs, E_kin_sign, E_kin_N_obs):
    return E_pot_obs[0]/E_kin_obs[0] / (E_pot_sign/E_kin_sign)

# Potential Energy / Kinetic Energy
custom_obs['E_pot_kin']= {
    'needs': ['Pot_scal', 'Kin_scal'],
    'function': E_pot_kin,
    'kwargs': {}
}

# %%
def R_k(obs, back, sign, N_orb, N_tau, dtau, latt,
        ks=((0., 0.),), mat=None, NNs=((1, 0), (0, 1), (-1, 0), (0, -1))):
    """RG-invariant quantity derived from a correlatian function.

    obs.shape = (N_orb, N_orb, N_tau, latt.N)
    back.shape = (N_orb,)
    """
    if mat is None:
        mat = np.identity(N_orb)
    out = 0
    for k in ks:
        n = latt.k_to_n(k)

        J1 = (obs[..., n].sum(axis=-1) * mat).sum()
        J2 = 0
        for NN in NNs:
            i = latt.nnlistk[n, NN[0], NN[1]]
            J2 += (obs[..., i].sum(axis=-1) * mat).sum() / len(NNs)
        out += (1 - J2/J1)

    return out / len(ks)

# RG-invariant quantity for ferromagnetic order
custom_obs['R_Ferro']= {
    'needs': ['SpinZ_eq'],
    'function': R_k,
    'kwargs': {'ks': [[0., 0.]]}
}

# RG-invariant quantity for antiferromagnetic order
custom_obs['R_AFM']= {
    'needs': ['SpinZ_eq'],
    'function': R_k,
    'kwargs': {'ks': [[np.pi, np.pi]]}
}

# %% [markdown]
# **New:** Check warmup and autocorrelation

# %%
sim.check_warmup(
    ['Ener_scal', 'Kin_scal', 'Pot_scal', 'E_pot_kin', 'R_Ferro', 'R_AFM'],
    custom_obs=custom_obs, gui='ipy'
)
# Out:
# VBox(children=(Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home',…

# %%
sim.check_rebin(
    ['Ener_scal', 'Kin_scal', 'Pot_scal', 'E_pot_kin', 'R_Ferro', 'R_AFM'],
    custom_obs=custom_obs, gui='ipy'
)
# Out:
# VBox(children=(Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home',…

# %% [markdown]
# **New:** Lattice symmetries in analysis

# %%
# Define list of transformations (Lattice, i) -> new_i
# Default analysis will average over all listed elements
sym_c4 = [
    lambda latt, i : i,
    lambda latt, i : latt.rotate(i, np.pi*0.5),
    lambda latt, i : latt.rotate(i, np.pi),
    lambda latt, i : latt.rotate(i, np.pi*1.5),
]

# %% [markdown]
# **5.** Perform anaylsis:

# %%
sim.analysis(symmetry=sym_c4, custom_obs=custom_obs, always=True)
# Out:
# ### Analyzing /home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1/Temp_0 ###
# /home/jonas/Programs/pyALF/Notebooks
# Custom observables:
# custom E_squared ['Ener_scal']
# custom E_pot_kin ['Pot_scal', 'Kin_scal']
# custom R_Ferro ['SpinZ_eq']
# custom R_AFM ['SpinZ_eq']
# Scalar observables:
# Acc_Temp_scal
# Ener_scal
# Kin_scal
# Part_scal
# Pot_scal
# Histogram observables:
# Equal time observables:
# Den_eq
# Green_eq
# SpinT_eq
# SpinXY_eq
# SpinZ_eq
# Time displaced observables:
# Den_tau
# /home/jonas/Programs/pyALF/py_alf/ana.py:604: RuntimeWarning: invalid value encountered in divide
#   J = J_obs[:, n] / J_sign
# Green_tau
# SpinT_tau
# SpinXY_tau
# SpinZ_tau
# ### Analyzing /home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1/Temp_1 ###
# /home/jonas/Programs/pyALF/Notebooks
# Custom observables:
# custom E_squared ['Ener_scal']
# custom E_pot_kin ['Pot_scal', 'Kin_scal']
# custom R_Ferro ['SpinZ_eq']
# custom R_AFM ['SpinZ_eq']
# Scalar observables:
# Acc_Temp_scal
# Ener_scal
# Kin_scal
# Part_scal
# Pot_scal
# Histogram observables:
# Equal time observables:
# Den_eq
# Green_eq
# SpinT_eq
# SpinXY_eq
# SpinZ_eq
# Time displaced observables:
# Den_tau
# Green_tau
# SpinT_tau
# SpinXY_tau
# SpinZ_tau
# ### Analyzing /home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1/Temp_2 ###
# /home/jonas/Programs/pyALF/Notebooks
# Custom observables:
# custom E_squared ['Ener_scal']
# custom E_pot_kin ['Pot_scal', 'Kin_scal']
# custom R_Ferro ['SpinZ_eq']
# custom R_AFM ['SpinZ_eq']
# Scalar observables:
# Acc_Temp_scal
# Ener_scal
# Kin_scal
# Part_scal
# Pot_scal
# Histogram observables:
# Equal time observables:
# Den_eq
# Green_eq
# SpinT_eq
# SpinXY_eq
# SpinZ_eq
# Time displaced observables:
# Den_tau
# Green_tau
# SpinT_tau
# SpinXY_tau
# SpinZ_tau
# ### Analyzing /home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1/Temp_3 ###
# /home/jonas/Programs/pyALF/Notebooks
# Custom observables:
# custom E_squared ['Ener_scal']
# custom E_pot_kin ['Pot_scal', 'Kin_scal']
# custom R_Ferro ['SpinZ_eq']
# custom R_AFM ['SpinZ_eq']
# Scalar observables:
# Acc_Temp_scal
# Ener_scal
# Kin_scal
# Part_scal
# Pot_scal
# Histogram observables:
# Equal time observables:
# Den_eq
# Green_eq
# SpinT_eq
# SpinXY_eq
# SpinZ_eq
# Time displaced observables:
# Den_tau
# Green_tau
# SpinT_tau
# SpinXY_tau
# SpinZ_tau

# %%
import py_alf

# %%
py_alf.lattice.__file__
# Out:
# '/home/jonas/Programs/pyALF/py_alf/lattice.py'

# %% [markdown]
# **6.** Read analysis results:

# %%
obs = sim.get_obs()
# Out:
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1/Temp_0
# No orbital locations saved.
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1/Temp_1
# No orbital locations saved.
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1/Temp_2
# No orbital locations saved.
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/temper_Hubbard_L1=4_L2=4_Square_U=1/Temp_3
# No orbital locations saved.

# %%
obs
# Out:
#                                                     continuous  ham_chem  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...           0       0.0
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...           0       0.0
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...           0       0.0
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...           0       0.0
#
#                                                     ham_t  ham_t2  ham_tperp  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...    1.0     1.0        1.0
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...    1.0     1.0        1.0
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...    1.0     1.0        1.0
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...    1.0     1.0        1.0
#
#                                                     ham_u  ham_u2  mz  l1  l2  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...    1.0     4.0   1   4   4
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...    2.0     4.0   1   4   4
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...    3.0     4.0   1   4   4
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...    4.0     4.0   1   4   4
#
#                                                     ...  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  ...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  ...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  ...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  ...
#
#                                                                                       SpinXY_tauK_err  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.0007537829802755554, 0.001000906647822049,...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.00243178709851971, 0.0031264318540468717, ...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.011851456553077474, 0.013262590165838991, ...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.011884911308827534, 0.019066548206282306, ...
#
#                                                                                           SpinXY_tauR  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.009944787718874703, -0.08311991130989815, ...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.03469925779297676, -0.1113870792700236, 0....
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.06234798458703581, -0.14978134845161875, 0...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.10215031272652919, -0.21160663260411136, 0...
#
#                                                                                       SpinXY_tauR_err  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.00016119836510819082, 0.000320431318209926...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.0029576766486150313, 0.0017367631289594355...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.004102466046595173, 0.003382323820260804, ...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.008147602010680762, 0.008181955281427997, ...
#
#                                                                                    SpinXY_tau_lattice  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  {'L1': [4.0, 0.0], 'L2': [0.0, 4.0], 'a1': [1....
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  {'L1': [4.0, 0.0], 'L2': [0.0, 4.0], 'a1': [1....
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  {'L1': [4.0, 0.0], 'L2': [0.0, 4.0], 'a1': [1....
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  {'L1': [4.0, 0.0], 'L2': [0.0, 4.0], 'a1': [1....
#
#                                                                                            SpinZ_tauK  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.5746678642065038, 0.4042353378830647, 0.57...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.6400538395583246, 0.4237024240459534, 0.64...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.6498125733916295, 0.44141749232737665, 0.6...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.6691865384045091, 0.43923305653759226, 0.6...
#
#                                                                                        SpinZ_tauK_err  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.002771160278785636, 0.0015890557936291962,...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.0054505382463837185, 0.0033465035246786705...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.007298412258979233, 0.005252665127658649, ...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.009538550016699227, 0.006805408791524047, ...
#
#                                                                                            SpinZ_tauR  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.009347278398136873, -0.08365604986949807, ...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.022933985952036797, -0.1036764359404749, 0...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.05339669939181033, -0.1421562399096341, 0....
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.10742510637022053, -0.21136486261390217, 0...
#
#                                                                                        SpinZ_tauR_err  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.0012839431818822365, 0.0011546500918624566...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.0024872787974700708, 0.0022508565991350466...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.0038862863294476173, 0.0036060845706908087...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  [[0.0055316434433876046, 0.00498201475247216, ...
#
#                                                                                     SpinZ_tau_lattice  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  {'L1': [4.0, 0.0], 'L2': [0.0, 4.0], 'a1': [1....
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  {'L1': [4.0, 0.0], 'L2': [0.0, 4.0], 'a1': [1....
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  {'L1': [4.0, 0.0], 'L2': [0.0, 4.0], 'a1': [1....
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  {'L1': [4.0, 0.0], 'L2': [0.0, 4.0], 'a1': [1....
#
#                                                                                               lattice
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  {'L1': [4.0, 0.0], 'L2': [0.0, 4.0], 'N_coord'...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  {'L1': [4.0, 0.0], 'L2': [0.0, 4.0], 'N_coord'...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  {'L1': [4.0, 0.0], 'L2': [0.0, 4.0], 'N_coord'...
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  {'L1': [4.0, 0.0], 'L2': [0.0, 4.0], 'N_coord'...
#
# [4 rows x 123 columns]

# %% [markdown]
# which are available for further analyses. For instance, the internal energy of the system (and its error) is accessed by:

# %%
obs[['ham_u', 'Ener_scal0', 'Ener_scal0_err', 'Ener_scal_sign', 'E_pot_kin', 'E_pot_kin_err', 'R_Ferro', 'R_AFM']]
# Out:
#                                                     ham_u  Ener_scal0  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...    1.0  -20.374940
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...    2.0  -17.388774
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...    3.0  -14.991747
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...    4.0  -13.218855
#
#                                                     Ener_scal0_err  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...        0.005014
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...        0.010125
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...        0.016534
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...        0.021768
#
#                                                     Ener_scal_sign  E_pot_kin  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...             1.0  -0.144617
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...             1.0  -0.252498
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...             1.0  -0.328918
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...             1.0  -0.372193
#
#                                                     E_pot_kin_err   R_Ferro  \
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...       0.000079 -0.525188
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...       0.000221 -0.436306
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...       0.000483 -0.388749
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...       0.000828 -1.232600
#
#                                                        R_AFM
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  0.353817
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  0.463888
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  0.575287
# /home/jonas/Programs/pyALF/Notebooks/ALF_data/t...  0.722344

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.errorbar(obs.ham_u, obs.E_pot_kin, obs.E_pot_kin_err)
# Out:
# <ErrorbarContainer object of 3 artists>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **New:** 2dplot on bravais lattice

# %%
from py_alf import Lattice

# %%
item = obs.iloc[0]

latt = Lattice(item.Den_eq_lattice)

latt.plot_k(item.Den_eqK[0, 0])
latt.plot_r(item.Den_eqR[0, 0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
